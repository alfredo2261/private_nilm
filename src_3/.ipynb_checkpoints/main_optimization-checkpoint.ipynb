# %%
import wandb
from data_loaders_optimization import make_train_data, make_test_val_data, make_model
from train import train, test
import torch
import time
import gc
import config_file
from clean_data import load_all_houses_with_device
import random
import optuna

# %%
wandb.login()

print(torch.cuda.is_available())

gc.collect()
torch.cuda.empty_cache()

print(torch.__version__)


config_ = config_file.config
# Out:
# wandb: Currently logged in as: nilm (use `wandb login --relogin` to force relogin)
# True
# 1.7.0

# %%
homes = load_all_houses_with_device(config_file.path, 'drye1')

# %%
drye1_homes = homes['dataid'].unique()

# %%
def objective(trial):
    params = {
        "hidden_size_1": trial.suggest_int("hidden_size_1", 30, 120),
        "hidden_size_2": trial.suggest_int("hidden_size_2", 80, 150),
        "fc1": trial.suggest_int("fc1", 180, 400),
        "fc2": trial.suggest_int("fc2", 15, 30),
        "weight_decay": trial.suggest_uniform("weight_decay", 0, 0.1),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-6, 1e-3),
        "window_size": trial.suggest_int("window_size", 2, 250)
    }
    
    model, result = model_pipeline(
        config_,
        'may_june_july',
        'aug',
        'drye1',
        params['window_size'],
        list(drye1_homes),
        [2358],
        params)
        
    return result[0]

# %%
def model_pipeline(hyperparameters, train_months, test_month, appliance, window_length, train_buildings,
                   test_buildings, params):
    with wandb.init(project="Drye1_optimization_new", config=hyperparameters):
        wandb.run.name = "Test1706normalize_over_dataset_hs1:32_hs2:200_fc1:200_fc2:100_1200epochs100batch_StepLR.0004_step50_gamma0.9_3dropout_weightdecay.00005_kern:7_outchan:16_4sigmoid_0maxpool_Trainbldgs:" + str(
            train_buildings)
        
        gc.collect()
        torch.cuda.empty_cache()
        
        config = wandb.config

        # lengths = [85320, 132480, 132480, 132480, 132480, 132480, 132480]

        model, criterion, optimizer = make_model(config, params)

        print(model)
        print("Window Length: ", window_length)

        wandb.watch(model, criterion, log="all", log_freq=10)

        example_ct = 0
        batch_ct = 0
        all_epochs = 0
        # all step_size=30 tests had gamma=0.5
        #scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.9, verbose=True)
        scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=params['learning_rate'], max_lr=1e-3, cycle_momentum=False, verbose=True)

        validation_loader, test_loader = make_test_val_data(config, test_month, appliance, window_length,
                                                            test_buildings)

        time_log = time.time()
        train_loader = make_train_data(config, train_months, appliance, window_length, train_buildings)
        model, example_ct, batch_ct, all_epochs = train(
            model,
            train_loader,
            validation_loader,
            criterion,
            optimizer,
            config,
            example_ct,
            batch_ct,
            all_epochs,
            scheduler)

        print("Time to train on one home: ", time.time() - time_log)

        results = test(model, test_loader, criterion)

    return model, results

# %%
if __name__ == "__main__":
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=25)
    
    print("best trial:")
    trial_ = study.best_trial
    
    print(trial_.values)
    print(trial_.params)
# Out:
# [I 2021-12-17 21:43:34,501] A new study created in memory with name: no-name-41b38b41-b5d6-43b4-ad7a-7861c0dd0360
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.19<br/>
#                 Syncing run <strong style="color:#cdcd00">electric-bird-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nilm/Drye1_optimization_new" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new</a><br/>
#                 Run page: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/1xjifatk" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/1xjifatk</a><br/>
#                 Run data is saved locally in <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_214334-1xjifatk</code><br/><br/>
# LSTM(
#   (conv1): Conv1d(1, 16, kernel_size=(7,), stride=(1,), padding=(3,))
#   (lstm1): LSTM(16, 114, num_layers=2, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(228, 139, num_layers=2, batch_first=True, bidirectional=True)
#   (linear1): Linear(in_features=278, out_features=232, bias=True)
#   (linear2): Linear(in_features=232, out_features=18, bias=True)
#   (linear3): Linear(in_features=18, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Window Length:  126
# Adjusting learning rate of group 0 to 2.4241e-06.
# Adjusting learning rate of group 0 to 2.9229e-06.
# Adjusting learning rate of group 0 to 3.4217e-06.
# Adjusting learning rate of group 0 to 3.9205e-06.
# Adjusting learning rate of group 0 to 4.4193e-06.
# Adjusting learning rate of group 0 to 4.9181e-06.
# Adjusting learning rate of group 0 to 5.4168e-06.
# Adjusting learning rate of group 0 to 5.9156e-06.
# Adjusting learning rate of group 0 to 6.4144e-06.
# Adjusting learning rate of group 0 to 6.9132e-06.
# Adjusting learning rate of group 0 to 7.4120e-06.
# Adjusting learning rate of group 0 to 7.9108e-06.
# Adjusting learning rate of group 0 to 8.4096e-06.
# Adjusting learning rate of group 0 to 8.9084e-06.
# Adjusting learning rate of group 0 to 9.4071e-06.
# Adjusting learning rate of group 0 to 9.9059e-06.
# Adjusting learning rate of group 0 to 1.0405e-05.
# Adjusting learning rate of group 0 to 1.0904e-05.
# Adjusting learning rate of group 0 to 1.1402e-05.
# Adjusting learning rate of group 0 to 1.1901e-05.
# Adjusting learning rate of group 0 to 1.2400e-05.
# Adjusting learning rate of group 0 to 1.2899e-05.
# Adjusting learning rate of group 0 to 1.3397e-05.
# Adjusting learning rate of group 0 to 1.3896e-05.
# Adjusting learning rate of group 0 to 1.4395e-05.
# Adjusting learning rate of group 0 to 1.4894e-05.
# Adjusting learning rate of group 0 to 1.5393e-05.
# Adjusting learning rate of group 0 to 1.5891e-05.
# Adjusting learning rate of group 0 to 1.6390e-05.
# Adjusting learning rate of group 0 to 1.6889e-05.
# Adjusting learning rate of group 0 to 1.7388e-05.
# Adjusting learning rate of group 0 to 1.7887e-05.
# Adjusting learning rate of group 0 to 1.8385e-05.
# Adjusting learning rate of group 0 to 1.8884e-05.
# Adjusting learning rate of group 0 to 1.9383e-05.
# Adjusting learning rate of group 0 to 1.9882e-05.
# Adjusting learning rate of group 0 to 2.0380e-05.
# Adjusting learning rate of group 0 to 2.0879e-05.
# Adjusting learning rate of group 0 to 2.1378e-05.
# Adjusting learning rate of group 0 to 2.1877e-05.
# Adjusting learning rate of group 0 to 2.2376e-05.
# trigger times: 0
# Loss after 19839 batches: 0.1825
# Adjusting learning rate of group 0 to 2.2874e-05.
# Adjusting learning rate of group 0 to 2.3373e-05.
# Adjusting learning rate of group 0 to 2.3872e-05.
# Adjusting learning rate of group 0 to 2.4371e-05.
# Adjusting learning rate of group 0 to 2.4870e-05.
# Adjusting learning rate of group 0 to 2.5368e-05.
# Adjusting learning rate of group 0 to 2.5867e-05.
# Adjusting learning rate of group 0 to 2.6366e-05.
# Adjusting learning rate of group 0 to 2.6865e-05.
# Adjusting learning rate of group 0 to 2.7364e-05.
# Adjusting learning rate of group 0 to 2.7862e-05.
# Adjusting learning rate of group 0 to 2.8361e-05.
# Adjusting learning rate of group 0 to 2.8860e-05.
# Adjusting learning rate of group 0 to 2.9359e-05.
# Adjusting learning rate of group 0 to 2.9857e-05.
# Adjusting learning rate of group 0 to 3.0356e-05.
# Adjusting learning rate of group 0 to 3.0855e-05.
# Adjusting learning rate of group 0 to 3.1354e-05.
# Adjusting learning rate of group 0 to 3.1853e-05.
# Adjusting learning rate of group 0 to 3.2351e-05.
# Adjusting learning rate of group 0 to 3.2850e-05.
# Adjusting learning rate of group 0 to 3.3349e-05.
# Adjusting learning rate of group 0 to 3.3848e-05.
# Adjusting learning rate of group 0 to 3.4347e-05.
# Adjusting learning rate of group 0 to 3.4845e-05.
# Adjusting learning rate of group 0 to 3.5344e-05.
# Adjusting learning rate of group 0 to 3.5843e-05.
# Adjusting learning rate of group 0 to 3.6342e-05.
# Adjusting learning rate of group 0 to 3.6840e-05.
# Adjusting learning rate of group 0 to 3.7339e-05.
# Adjusting learning rate of group 0 to 3.7838e-05.
# Adjusting learning rate of group 0 to 3.8337e-05.
# Adjusting learning rate of group 0 to 3.8836e-05.
# Adjusting learning rate of group 0 to 3.9334e-05.
# Adjusting learning rate of group 0 to 3.9833e-05.
# Adjusting learning rate of group 0 to 4.0332e-05.
# Adjusting learning rate of group 0 to 4.0831e-05.
# Adjusting learning rate of group 0 to 4.1330e-05.
# Adjusting learning rate of group 0 to 4.1828e-05.
# Adjusting learning rate of group 0 to 4.2327e-05.
# trigger times: 0
# Loss after 39678 batches: 0.1585
# Adjusting learning rate of group 0 to 4.2826e-05.
# Adjusting learning rate of group 0 to 4.3325e-05.
# Adjusting learning rate of group 0 to 4.3824e-05.
# Adjusting learning rate of group 0 to 4.4322e-05.
# Adjusting learning rate of group 0 to 4.4821e-05.
# Adjusting learning rate of group 0 to 4.5320e-05.
# Adjusting learning rate of group 0 to 4.5819e-05.
# Adjusting learning rate of group 0 to 4.6317e-05.
# Adjusting learning rate of group 0 to 4.6816e-05.
# Adjusting learning rate of group 0 to 4.7315e-05.
# Adjusting learning rate of group 0 to 4.7814e-05.
# Adjusting learning rate of group 0 to 4.8313e-05.
# Adjusting learning rate of group 0 to 4.8811e-05.
# Adjusting learning rate of group 0 to 4.9310e-05.
# Adjusting learning rate of group 0 to 4.9809e-05.
# Adjusting learning rate of group 0 to 5.0308e-05.
# Adjusting learning rate of group 0 to 5.0807e-05.
# Adjusting learning rate of group 0 to 5.1305e-05.
# Adjusting learning rate of group 0 to 5.1804e-05.
# Adjusting learning rate of group 0 to 5.2303e-05.
# Adjusting learning rate of group 0 to 5.2802e-05.
# Adjusting learning rate of group 0 to 5.3300e-05.
# Adjusting learning rate of group 0 to 5.3799e-05.
# Adjusting learning rate of group 0 to 5.4298e-05.
# Adjusting learning rate of group 0 to 5.4797e-05.
# Adjusting learning rate of group 0 to 5.5296e-05.
# Adjusting learning rate of group 0 to 5.5794e-05.
# Adjusting learning rate of group 0 to 5.6293e-05.
# Adjusting learning rate of group 0 to 5.6792e-05.
# Adjusting learning rate of group 0 to 5.7291e-05.
# Adjusting learning rate of group 0 to 5.7790e-05.
# Adjusting learning rate of group 0 to 5.8288e-05.
# Adjusting learning rate of group 0 to 5.8787e-05.
# Adjusting learning rate of group 0 to 5.9286e-05.
# Adjusting learning rate of group 0 to 5.9785e-05.
# Adjusting learning rate of group 0 to 6.0284e-05.
# Adjusting learning rate of group 0 to 6.0782e-05.
# Adjusting learning rate of group 0 to 6.1281e-05.
# Adjusting learning rate of group 0 to 6.1780e-05.
# Adjusting learning rate of group 0 to 6.2279e-05.
# trigger times: 0
# Loss after 59517 batches: 0.1288
# Adjusting learning rate of group 0 to 6.2777e-05.
# Adjusting learning rate of group 0 to 6.3276e-05.
# Adjusting learning rate of group 0 to 6.3775e-05.
# Adjusting learning rate of group 0 to 6.4274e-05.
# Adjusting learning rate of group 0 to 6.4773e-05.
# Adjusting learning rate of group 0 to 6.5271e-05.
# Adjusting learning rate of group 0 to 6.5770e-05.
# Adjusting learning rate of group 0 to 6.6269e-05.
# Adjusting learning rate of group 0 to 6.6768e-05.
# Adjusting learning rate of group 0 to 6.7267e-05.
# Adjusting learning rate of group 0 to 6.7765e-05.
# Adjusting learning rate of group 0 to 6.8264e-05.
# Adjusting learning rate of group 0 to 6.8763e-05.
# Adjusting learning rate of group 0 to 6.9262e-05.
# Adjusting learning rate of group 0 to 6.9760e-05.
# Adjusting learning rate of group 0 to 7.0259e-05.
# Adjusting learning rate of group 0 to 7.0758e-05.
# Adjusting learning rate of group 0 to 7.1257e-05.
# Adjusting learning rate of group 0 to 7.1756e-05.
# Adjusting learning rate of group 0 to 7.2254e-05.
# Adjusting learning rate of group 0 to 7.2753e-05.
# Adjusting learning rate of group 0 to 7.3252e-05.
# Adjusting learning rate of group 0 to 7.3751e-05.
# Adjusting learning rate of group 0 to 7.4250e-05.
# Adjusting learning rate of group 0 to 7.4748e-05.
# Adjusting learning rate of group 0 to 7.5247e-05.
# Adjusting learning rate of group 0 to 7.5746e-05.
# Adjusting learning rate of group 0 to 7.6245e-05.
# Adjusting learning rate of group 0 to 7.6744e-05.
# Adjusting learning rate of group 0 to 7.7242e-05.
# Adjusting learning rate of group 0 to 7.7741e-05.
# Adjusting learning rate of group 0 to 7.8240e-05.
# Adjusting learning rate of group 0 to 7.8739e-05.
# Adjusting learning rate of group 0 to 7.9237e-05.
# Adjusting learning rate of group 0 to 7.9736e-05.
# Adjusting learning rate of group 0 to 8.0235e-05.
# Adjusting learning rate of group 0 to 8.0734e-05.
# Adjusting learning rate of group 0 to 8.1233e-05.
# Adjusting learning rate of group 0 to 8.1731e-05.
# Adjusting learning rate of group 0 to 8.2230e-05.
# trigger times: 0
# Loss after 79356 batches: 0.0972
# Adjusting learning rate of group 0 to 8.2729e-05.
# Adjusting learning rate of group 0 to 8.3228e-05.
# Adjusting learning rate of group 0 to 8.3727e-05.
# Adjusting learning rate of group 0 to 8.4225e-05.
# Adjusting learning rate of group 0 to 8.4724e-05.
# Adjusting learning rate of group 0 to 8.5223e-05.
# Adjusting learning rate of group 0 to 8.5722e-05.
# Adjusting learning rate of group 0 to 8.6220e-05.
# Adjusting learning rate of group 0 to 8.6719e-05.
# Adjusting learning rate of group 0 to 8.7218e-05.
# Adjusting learning rate of group 0 to 8.7717e-05.
# Adjusting learning rate of group 0 to 8.8216e-05.
# Adjusting learning rate of group 0 to 8.8714e-05.
# Adjusting learning rate of group 0 to 8.9213e-05.
# Adjusting learning rate of group 0 to 8.9712e-05.
# Adjusting learning rate of group 0 to 9.0211e-05.
# Adjusting learning rate of group 0 to 9.0710e-05.
# Adjusting learning rate of group 0 to 9.1208e-05.
# Adjusting learning rate of group 0 to 9.1707e-05.
# Adjusting learning rate of group 0 to 9.2206e-05.
# Adjusting learning rate of group 0 to 9.2705e-05.
# Adjusting learning rate of group 0 to 9.3204e-05.
# Adjusting learning rate of group 0 to 9.3702e-05.
# Adjusting learning rate of group 0 to 9.4201e-05.
# Adjusting learning rate of group 0 to 9.4700e-05.
# Adjusting learning rate of group 0 to 9.5199e-05.
# Adjusting learning rate of group 0 to 9.5697e-05.
# Adjusting learning rate of group 0 to 9.6196e-05.
# Adjusting learning rate of group 0 to 9.6695e-05.
# Adjusting learning rate of group 0 to 9.7194e-05.
# Adjusting learning rate of group 0 to 9.7693e-05.
# Adjusting learning rate of group 0 to 9.8191e-05.
# Adjusting learning rate of group 0 to 9.8690e-05.
# Adjusting learning rate of group 0 to 9.9189e-05.
# Adjusting learning rate of group 0 to 9.9688e-05.
# Adjusting learning rate of group 0 to 1.0019e-04.
# Adjusting learning rate of group 0 to 1.0069e-04.
# Adjusting learning rate of group 0 to 1.0118e-04.
# Adjusting learning rate of group 0 to 1.0168e-04.
# Adjusting learning rate of group 0 to 1.0218e-04.
# trigger times: 0
# Loss after 99195 batches: 0.0751
# Adjusting learning rate of group 0 to 1.0268e-04.
# Adjusting learning rate of group 0 to 1.0318e-04.
# Adjusting learning rate of group 0 to 1.0368e-04.
# Adjusting learning rate of group 0 to 1.0418e-04.
# Adjusting learning rate of group 0 to 1.0468e-04.
# Adjusting learning rate of group 0 to 1.0517e-04.
# Adjusting learning rate of group 0 to 1.0567e-04.
# Adjusting learning rate of group 0 to 1.0617e-04.
# Adjusting learning rate of group 0 to 1.0667e-04.
# Adjusting learning rate of group 0 to 1.0717e-04.
# Adjusting learning rate of group 0 to 1.0767e-04.
# Adjusting learning rate of group 0 to 1.0817e-04.
# Adjusting learning rate of group 0 to 1.0867e-04.
# Adjusting learning rate of group 0 to 1.0916e-04.
# Adjusting learning rate of group 0 to 1.0966e-04.
# Adjusting learning rate of group 0 to 1.1016e-04.
# Adjusting learning rate of group 0 to 1.1066e-04.
# Adjusting learning rate of group 0 to 1.1116e-04.
# Adjusting learning rate of group 0 to 1.1166e-04.
# Adjusting learning rate of group 0 to 1.1216e-04.
# Adjusting learning rate of group 0 to 1.1266e-04.
# Adjusting learning rate of group 0 to 1.1316e-04.
# Adjusting learning rate of group 0 to 1.1365e-04.
# Adjusting learning rate of group 0 to 1.1415e-04.
# Adjusting learning rate of group 0 to 1.1465e-04.
# Adjusting learning rate of group 0 to 1.1515e-04.
# Adjusting learning rate of group 0 to 1.1565e-04.
# Adjusting learning rate of group 0 to 1.1615e-04.
# Adjusting learning rate of group 0 to 1.1665e-04.
# Adjusting learning rate of group 0 to 1.1715e-04.
# Adjusting learning rate of group 0 to 1.1764e-04.
# Adjusting learning rate of group 0 to 1.1814e-04.
# Adjusting learning rate of group 0 to 1.1864e-04.
# Adjusting learning rate of group 0 to 1.1914e-04.
# Adjusting learning rate of group 0 to 1.1964e-04.
# Adjusting learning rate of group 0 to 1.2014e-04.
# Adjusting learning rate of group 0 to 1.2064e-04.
# Adjusting learning rate of group 0 to 1.2114e-04.
# Adjusting learning rate of group 0 to 1.2163e-04.
# Adjusting learning rate of group 0 to 1.2213e-04.
# trigger times: 0
# Loss after 119034 batches: 0.0623
# Adjusting learning rate of group 0 to 1.2263e-04.
# Adjusting learning rate of group 0 to 1.2313e-04.
# Adjusting learning rate of group 0 to 1.2363e-04.
# Adjusting learning rate of group 0 to 1.2413e-04.
# Adjusting learning rate of group 0 to 1.2463e-04.
# Adjusting learning rate of group 0 to 1.2513e-04.
# Adjusting learning rate of group 0 to 1.2562e-04.
# Adjusting learning rate of group 0 to 1.2612e-04.
# Adjusting learning rate of group 0 to 1.2662e-04.
# Adjusting learning rate of group 0 to 1.2712e-04.
# Adjusting learning rate of group 0 to 1.2762e-04.
# Adjusting learning rate of group 0 to 1.2812e-04.
# Adjusting learning rate of group 0 to 1.2862e-04.
# Adjusting learning rate of group 0 to 1.2912e-04.
# Adjusting learning rate of group 0 to 1.2962e-04.
# Adjusting learning rate of group 0 to 1.3011e-04.
# Adjusting learning rate of group 0 to 1.3061e-04.
# Adjusting learning rate of group 0 to 1.3111e-04.
# Adjusting learning rate of group 0 to 1.3161e-04.
# Adjusting learning rate of group 0 to 1.3211e-04.
# Adjusting learning rate of group 0 to 1.3261e-04.
# Adjusting learning rate of group 0 to 1.3311e-04.
# Adjusting learning rate of group 0 to 1.3361e-04.
# Adjusting learning rate of group 0 to 1.3410e-04.
# Adjusting learning rate of group 0 to 1.3460e-04.
# Adjusting learning rate of group 0 to 1.3510e-04.
# Adjusting learning rate of group 0 to 1.3560e-04.
# Adjusting learning rate of group 0 to 1.3610e-04.
# Adjusting learning rate of group 0 to 1.3660e-04.
# Adjusting learning rate of group 0 to 1.3710e-04.
# Adjusting learning rate of group 0 to 1.3760e-04.
# Adjusting learning rate of group 0 to 1.3809e-04.
# Adjusting learning rate of group 0 to 1.3859e-04.
# Adjusting learning rate of group 0 to 1.3909e-04.
# Adjusting learning rate of group 0 to 1.3959e-04.
# Adjusting learning rate of group 0 to 1.4009e-04.
# Adjusting learning rate of group 0 to 1.4059e-04.
# Adjusting learning rate of group 0 to 1.4109e-04.
# Adjusting learning rate of group 0 to 1.4159e-04.
# Adjusting learning rate of group 0 to 1.4208e-04.
# trigger times: 0
# Loss after 138873 batches: 0.0552
# Adjusting learning rate of group 0 to 1.4258e-04.
# Adjusting learning rate of group 0 to 1.4308e-04.
# Adjusting learning rate of group 0 to 1.4358e-04.
# Adjusting learning rate of group 0 to 1.4408e-04.
# Adjusting learning rate of group 0 to 1.4458e-04.
# Adjusting learning rate of group 0 to 1.4508e-04.
# Adjusting learning rate of group 0 to 1.4558e-04.
# Adjusting learning rate of group 0 to 1.4608e-04.
# Adjusting learning rate of group 0 to 1.4657e-04.
# Adjusting learning rate of group 0 to 1.4707e-04.
# Adjusting learning rate of group 0 to 1.4757e-04.
# Adjusting learning rate of group 0 to 1.4807e-04.
# Adjusting learning rate of group 0 to 1.4857e-04.
# Adjusting learning rate of group 0 to 1.4907e-04.
# Adjusting learning rate of group 0 to 1.4957e-04.
# Adjusting learning rate of group 0 to 1.5007e-04.
# Adjusting learning rate of group 0 to 1.5056e-04.
# Adjusting learning rate of group 0 to 1.5106e-04.
# Adjusting learning rate of group 0 to 1.5156e-04.
# Adjusting learning rate of group 0 to 1.5206e-04.
# Adjusting learning rate of group 0 to 1.5256e-04.
# Adjusting learning rate of group 0 to 1.5306e-04.
# Adjusting learning rate of group 0 to 1.5356e-04.
# Adjusting learning rate of group 0 to 1.5406e-04.
# Adjusting learning rate of group 0 to 1.5455e-04.
# Adjusting learning rate of group 0 to 1.5505e-04.
# Adjusting learning rate of group 0 to 1.5555e-04.
# Adjusting learning rate of group 0 to 1.5605e-04.
# Adjusting learning rate of group 0 to 1.5655e-04.
# Adjusting learning rate of group 0 to 1.5705e-04.
# Adjusting learning rate of group 0 to 1.5755e-04.
# Adjusting learning rate of group 0 to 1.5805e-04.
# Adjusting learning rate of group 0 to 1.5854e-04.
# Adjusting learning rate of group 0 to 1.5904e-04.
# Adjusting learning rate of group 0 to 1.5954e-04.
# Adjusting learning rate of group 0 to 1.6004e-04.
# Adjusting learning rate of group 0 to 1.6054e-04.
# Adjusting learning rate of group 0 to 1.6104e-04.
# Adjusting learning rate of group 0 to 1.6154e-04.
# Adjusting learning rate of group 0 to 1.6204e-04.
# trigger times: 0
# Loss after 158712 batches: 0.0514
# Adjusting learning rate of group 0 to 1.6254e-04.
# Adjusting learning rate of group 0 to 1.6303e-04.
# Adjusting learning rate of group 0 to 1.6353e-04.
# Adjusting learning rate of group 0 to 1.6403e-04.
# Adjusting learning rate of group 0 to 1.6453e-04.
# Adjusting learning rate of group 0 to 1.6503e-04.
# Adjusting learning rate of group 0 to 1.6553e-04.
# Adjusting learning rate of group 0 to 1.6603e-04.
# Adjusting learning rate of group 0 to 1.6653e-04.
# Adjusting learning rate of group 0 to 1.6702e-04.
# Adjusting learning rate of group 0 to 1.6752e-04.
# Adjusting learning rate of group 0 to 1.6802e-04.
# Adjusting learning rate of group 0 to 1.6852e-04.
# Adjusting learning rate of group 0 to 1.6902e-04.
# Adjusting learning rate of group 0 to 1.6952e-04.
# Adjusting learning rate of group 0 to 1.7002e-04.
# Adjusting learning rate of group 0 to 1.7052e-04.
# Adjusting learning rate of group 0 to 1.7101e-04.
# Adjusting learning rate of group 0 to 1.7151e-04.
# Adjusting learning rate of group 0 to 1.7201e-04.
# Adjusting learning rate of group 0 to 1.7251e-04.
# Adjusting learning rate of group 0 to 1.7301e-04.
# Adjusting learning rate of group 0 to 1.7351e-04.
# Adjusting learning rate of group 0 to 1.7401e-04.
# Adjusting learning rate of group 0 to 1.7451e-04.
# Adjusting learning rate of group 0 to 1.7500e-04.
# Adjusting learning rate of group 0 to 1.7550e-04.
# Adjusting learning rate of group 0 to 1.7600e-04.
# Adjusting learning rate of group 0 to 1.7650e-04.
# Adjusting learning rate of group 0 to 1.7700e-04.
# Adjusting learning rate of group 0 to 1.7750e-04.
# Adjusting learning rate of group 0 to 1.7800e-04.
# Adjusting learning rate of group 0 to 1.7850e-04.
# Adjusting learning rate of group 0 to 1.7900e-04.
# Adjusting learning rate of group 0 to 1.7949e-04.
# Adjusting learning rate of group 0 to 1.7999e-04.
# Adjusting learning rate of group 0 to 1.8049e-04.
# Adjusting learning rate of group 0 to 1.8099e-04.
# Adjusting learning rate of group 0 to 1.8149e-04.
# Adjusting learning rate of group 0 to 1.8199e-04.
# trigger times: 0
# Loss after 178551 batches: 0.0492
# Adjusting learning rate of group 0 to 1.8249e-04.
# Adjusting learning rate of group 0 to 1.8299e-04.
# Adjusting learning rate of group 0 to 1.8348e-04.
# Adjusting learning rate of group 0 to 1.8398e-04.
# Adjusting learning rate of group 0 to 1.8448e-04.
# Adjusting learning rate of group 0 to 1.8498e-04.
# Adjusting learning rate of group 0 to 1.8548e-04.
# Adjusting learning rate of group 0 to 1.8598e-04.
# Adjusting learning rate of group 0 to 1.8648e-04.
# Adjusting learning rate of group 0 to 1.8698e-04.
# Adjusting learning rate of group 0 to 1.8747e-04.
# Adjusting learning rate of group 0 to 1.8797e-04.
# Adjusting learning rate of group 0 to 1.8847e-04.
# Adjusting learning rate of group 0 to 1.8897e-04.
# Adjusting learning rate of group 0 to 1.8947e-04.
# Adjusting learning rate of group 0 to 1.8997e-04.
# Adjusting learning rate of group 0 to 1.9047e-04.
# Adjusting learning rate of group 0 to 1.9097e-04.
# Adjusting learning rate of group 0 to 1.9146e-04.
# Adjusting learning rate of group 0 to 1.9196e-04.
# Adjusting learning rate of group 0 to 1.9246e-04.
# Adjusting learning rate of group 0 to 1.9296e-04.
# Adjusting learning rate of group 0 to 1.9346e-04.
# Adjusting learning rate of group 0 to 1.9396e-04.
# Adjusting learning rate of group 0 to 1.9446e-04.
# Adjusting learning rate of group 0 to 1.9496e-04.
# Adjusting learning rate of group 0 to 1.9546e-04.
# Adjusting learning rate of group 0 to 1.9595e-04.
# Adjusting learning rate of group 0 to 1.9645e-04.
# Adjusting learning rate of group 0 to 1.9695e-04.
# Adjusting learning rate of group 0 to 1.9745e-04.
# Adjusting learning rate of group 0 to 1.9795e-04.
# Adjusting learning rate of group 0 to 1.9845e-04.
# Adjusting learning rate of group 0 to 1.9895e-04.
# Adjusting learning rate of group 0 to 1.9945e-04.
# Adjusting learning rate of group 0 to 1.9994e-04.
# Adjusting learning rate of group 0 to 2.0044e-04.
# Adjusting learning rate of group 0 to 2.0094e-04.
# Adjusting learning rate of group 0 to 2.0144e-04.
# Adjusting learning rate of group 0 to 2.0194e-04.
# trigger times: 0
# Loss after 198390 batches: 0.0479
# Adjusting learning rate of group 0 to 2.0244e-04.
# Adjusting learning rate of group 0 to 2.0294e-04.
# Adjusting learning rate of group 0 to 2.0344e-04.
# Adjusting learning rate of group 0 to 2.0393e-04.
# Adjusting learning rate of group 0 to 2.0443e-04.
# Adjusting learning rate of group 0 to 2.0493e-04.
# Adjusting learning rate of group 0 to 2.0543e-04.
# Adjusting learning rate of group 0 to 2.0593e-04.
# Adjusting learning rate of group 0 to 2.0643e-04.
# Adjusting learning rate of group 0 to 2.0693e-04.
# Adjusting learning rate of group 0 to 2.0743e-04.
# Adjusting learning rate of group 0 to 2.0792e-04.
# Adjusting learning rate of group 0 to 2.0842e-04.
# Adjusting learning rate of group 0 to 2.0892e-04.
# Adjusting learning rate of group 0 to 2.0942e-04.
# Adjusting learning rate of group 0 to 2.0992e-04.
# Adjusting learning rate of group 0 to 2.1042e-04.
# Adjusting learning rate of group 0 to 2.1092e-04.
# Adjusting learning rate of group 0 to 2.1142e-04.
# Adjusting learning rate of group 0 to 2.1192e-04.
# Adjusting learning rate of group 0 to 2.1241e-04.
# Adjusting learning rate of group 0 to 2.1291e-04.
# Adjusting learning rate of group 0 to 2.1341e-04.
# Adjusting learning rate of group 0 to 2.1391e-04.
# Adjusting learning rate of group 0 to 2.1441e-04.
# Adjusting learning rate of group 0 to 2.1491e-04.
# Adjusting learning rate of group 0 to 2.1541e-04.
# Adjusting learning rate of group 0 to 2.1591e-04.
# Adjusting learning rate of group 0 to 2.1640e-04.
# Adjusting learning rate of group 0 to 2.1690e-04.
# Adjusting learning rate of group 0 to 2.1740e-04.
# Adjusting learning rate of group 0 to 2.1790e-04.
# Adjusting learning rate of group 0 to 2.1840e-04.
# Adjusting learning rate of group 0 to 2.1890e-04.
# Adjusting learning rate of group 0 to 2.1940e-04.
# Adjusting learning rate of group 0 to 2.1990e-04.
# Adjusting learning rate of group 0 to 2.2039e-04.
# Adjusting learning rate of group 0 to 2.2089e-04.
# Adjusting learning rate of group 0 to 2.2139e-04.
# Adjusting learning rate of group 0 to 2.2189e-04.
# trigger times: 0
# Loss after 218229 batches: 0.0471
# Adjusting learning rate of group 0 to 2.2239e-04.
# Adjusting learning rate of group 0 to 2.2289e-04.
# Adjusting learning rate of group 0 to 2.2339e-04.
# Adjusting learning rate of group 0 to 2.2389e-04.
# Adjusting learning rate of group 0 to 2.2438e-04.
# Adjusting learning rate of group 0 to 2.2488e-04.
# Adjusting learning rate of group 0 to 2.2538e-04.
# Adjusting learning rate of group 0 to 2.2588e-04.
# Adjusting learning rate of group 0 to 2.2638e-04.
# Adjusting learning rate of group 0 to 2.2688e-04.
# Adjusting learning rate of group 0 to 2.2738e-04.
# Adjusting learning rate of group 0 to 2.2788e-04.
# Adjusting learning rate of group 0 to 2.2838e-04.
# Adjusting learning rate of group 0 to 2.2887e-04.
# Adjusting learning rate of group 0 to 2.2937e-04.
# Adjusting learning rate of group 0 to 2.2987e-04.
# Adjusting learning rate of group 0 to 2.3037e-04.
# Adjusting learning rate of group 0 to 2.3087e-04.
# Adjusting learning rate of group 0 to 2.3137e-04.
# Adjusting learning rate of group 0 to 2.3187e-04.
# Adjusting learning rate of group 0 to 2.3237e-04.
# Adjusting learning rate of group 0 to 2.3286e-04.
# Adjusting learning rate of group 0 to 2.3336e-04.
# Adjusting learning rate of group 0 to 2.3386e-04.
# Adjusting learning rate of group 0 to 2.3436e-04.
# Adjusting learning rate of group 0 to 2.3486e-04.
# Adjusting learning rate of group 0 to 2.3536e-04.
# Adjusting learning rate of group 0 to 2.3586e-04.
# Adjusting learning rate of group 0 to 2.3636e-04.
# Adjusting learning rate of group 0 to 2.3685e-04.
# Adjusting learning rate of group 0 to 2.3735e-04.
# Adjusting learning rate of group 0 to 2.3785e-04.
# Adjusting learning rate of group 0 to 2.3835e-04.
# Adjusting learning rate of group 0 to 2.3885e-04.
# Adjusting learning rate of group 0 to 2.3935e-04.
# Adjusting learning rate of group 0 to 2.3985e-04.
# Adjusting learning rate of group 0 to 2.4035e-04.
# Adjusting learning rate of group 0 to 2.4084e-04.
# Adjusting learning rate of group 0 to 2.4134e-04.
# Adjusting learning rate of group 0 to 2.4184e-04.
# trigger times: 1
# Loss after 238068 batches: 0.0465
# Adjusting learning rate of group 0 to 2.4234e-04.
# Adjusting learning rate of group 0 to 2.4284e-04.
# Adjusting learning rate of group 0 to 2.4334e-04.
# Adjusting learning rate of group 0 to 2.4384e-04.
# Adjusting learning rate of group 0 to 2.4434e-04.
# Adjusting learning rate of group 0 to 2.4484e-04.
# Adjusting learning rate of group 0 to 2.4533e-04.
# Adjusting learning rate of group 0 to 2.4583e-04.
# Adjusting learning rate of group 0 to 2.4633e-04.
# Adjusting learning rate of group 0 to 2.4683e-04.
# Adjusting learning rate of group 0 to 2.4733e-04.
# Adjusting learning rate of group 0 to 2.4783e-04.
# Adjusting learning rate of group 0 to 2.4833e-04.
# Adjusting learning rate of group 0 to 2.4883e-04.
# Adjusting learning rate of group 0 to 2.4932e-04.
# Adjusting learning rate of group 0 to 2.4982e-04.
# Adjusting learning rate of group 0 to 2.5032e-04.
# Adjusting learning rate of group 0 to 2.5082e-04.
# Adjusting learning rate of group 0 to 2.5132e-04.
# Adjusting learning rate of group 0 to 2.5182e-04.
# Adjusting learning rate of group 0 to 2.5232e-04.
# Adjusting learning rate of group 0 to 2.5282e-04.
# Adjusting learning rate of group 0 to 2.5331e-04.
# Adjusting learning rate of group 0 to 2.5381e-04.
# Adjusting learning rate of group 0 to 2.5431e-04.
# Adjusting learning rate of group 0 to 2.5481e-04.
# Adjusting learning rate of group 0 to 2.5531e-04.
# Adjusting learning rate of group 0 to 2.5581e-04.
# Adjusting learning rate of group 0 to 2.5631e-04.
# Adjusting learning rate of group 0 to 2.5681e-04.
# Adjusting learning rate of group 0 to 2.5730e-04.
# Adjusting learning rate of group 0 to 2.5780e-04.
# Adjusting learning rate of group 0 to 2.5830e-04.
# Adjusting learning rate of group 0 to 2.5880e-04.
# Adjusting learning rate of group 0 to 2.5930e-04.
# Adjusting learning rate of group 0 to 2.5980e-04.
# Adjusting learning rate of group 0 to 2.6030e-04.
# Adjusting learning rate of group 0 to 2.6080e-04.
# Adjusting learning rate of group 0 to 2.6130e-04.
# Adjusting learning rate of group 0 to 2.6179e-04.
# trigger times: 0
# Loss after 257907 batches: 0.0461
# Adjusting learning rate of group 0 to 2.6229e-04.
# Adjusting learning rate of group 0 to 2.6279e-04.
# Adjusting learning rate of group 0 to 2.6329e-04.
# Adjusting learning rate of group 0 to 2.6379e-04.
# Adjusting learning rate of group 0 to 2.6429e-04.
# Adjusting learning rate of group 0 to 2.6479e-04.
# Adjusting learning rate of group 0 to 2.6529e-04.
# Adjusting learning rate of group 0 to 2.6578e-04.
# Adjusting learning rate of group 0 to 2.6628e-04.
# Adjusting learning rate of group 0 to 2.6678e-04.
# Adjusting learning rate of group 0 to 2.6728e-04.
# Adjusting learning rate of group 0 to 2.6778e-04.
# Adjusting learning rate of group 0 to 2.6828e-04.
# Adjusting learning rate of group 0 to 2.6878e-04.
# Adjusting learning rate of group 0 to 2.6928e-04.
# Adjusting learning rate of group 0 to 2.6977e-04.
# Adjusting learning rate of group 0 to 2.7027e-04.
# Adjusting learning rate of group 0 to 2.7077e-04.
# Adjusting learning rate of group 0 to 2.7127e-04.
# Adjusting learning rate of group 0 to 2.7177e-04.
# Adjusting learning rate of group 0 to 2.7227e-04.
# Adjusting learning rate of group 0 to 2.7277e-04.
# Adjusting learning rate of group 0 to 2.7327e-04.
# Adjusting learning rate of group 0 to 2.7376e-04.
# Adjusting learning rate of group 0 to 2.7426e-04.
# Adjusting learning rate of group 0 to 2.7476e-04.
# Adjusting learning rate of group 0 to 2.7526e-04.
# Adjusting learning rate of group 0 to 2.7576e-04.
# Adjusting learning rate of group 0 to 2.7626e-04.
# Adjusting learning rate of group 0 to 2.7676e-04.
# Adjusting learning rate of group 0 to 2.7726e-04.
# Adjusting learning rate of group 0 to 2.7776e-04.
# Adjusting learning rate of group 0 to 2.7825e-04.
# Adjusting learning rate of group 0 to 2.7875e-04.
# Adjusting learning rate of group 0 to 2.7925e-04.
# Adjusting learning rate of group 0 to 2.7975e-04.
# Adjusting learning rate of group 0 to 2.8025e-04.
# Adjusting learning rate of group 0 to 2.8075e-04.
# Adjusting learning rate of group 0 to 2.8125e-04.
# Adjusting learning rate of group 0 to 2.8175e-04.
# trigger times: 1
# Loss after 277746 batches: 0.0457
# Adjusting learning rate of group 0 to 2.8224e-04.
# Adjusting learning rate of group 0 to 2.8274e-04.
# Adjusting learning rate of group 0 to 2.8324e-04.
# Adjusting learning rate of group 0 to 2.8374e-04.
# Adjusting learning rate of group 0 to 2.8424e-04.
# Adjusting learning rate of group 0 to 2.8474e-04.
# Adjusting learning rate of group 0 to 2.8524e-04.
# Adjusting learning rate of group 0 to 2.8574e-04.
# Adjusting learning rate of group 0 to 2.8623e-04.
# Adjusting learning rate of group 0 to 2.8673e-04.
# Adjusting learning rate of group 0 to 2.8723e-04.
# Adjusting learning rate of group 0 to 2.8773e-04.
# Adjusting learning rate of group 0 to 2.8823e-04.
# Adjusting learning rate of group 0 to 2.8873e-04.
# Adjusting learning rate of group 0 to 2.8923e-04.
# Adjusting learning rate of group 0 to 2.8973e-04.
# Adjusting learning rate of group 0 to 2.9022e-04.
# Adjusting learning rate of group 0 to 2.9072e-04.
# Adjusting learning rate of group 0 to 2.9122e-04.
# Adjusting learning rate of group 0 to 2.9172e-04.
# Adjusting learning rate of group 0 to 2.9222e-04.
# Adjusting learning rate of group 0 to 2.9272e-04.
# Adjusting learning rate of group 0 to 2.9322e-04.
# Adjusting learning rate of group 0 to 2.9372e-04.
# Adjusting learning rate of group 0 to 2.9422e-04.
# Adjusting learning rate of group 0 to 2.9471e-04.
# Adjusting learning rate of group 0 to 2.9521e-04.
# Adjusting learning rate of group 0 to 2.9571e-04.
# Adjusting learning rate of group 0 to 2.9621e-04.
# Adjusting learning rate of group 0 to 2.9671e-04.
# Adjusting learning rate of group 0 to 2.9721e-04.
# Adjusting learning rate of group 0 to 2.9771e-04.
# Adjusting learning rate of group 0 to 2.9821e-04.
# Adjusting learning rate of group 0 to 2.9870e-04.
# Adjusting learning rate of group 0 to 2.9920e-04.
# Adjusting learning rate of group 0 to 2.9970e-04.
# Adjusting learning rate of group 0 to 3.0020e-04.
# Adjusting learning rate of group 0 to 3.0070e-04.
# Adjusting learning rate of group 0 to 3.0120e-04.
# Adjusting learning rate of group 0 to 3.0170e-04.
# trigger times: 2
# Loss after 297585 batches: 0.0455
# Adjusting learning rate of group 0 to 3.0220e-04.
# Adjusting learning rate of group 0 to 3.0269e-04.
# Adjusting learning rate of group 0 to 3.0319e-04.
# Adjusting learning rate of group 0 to 3.0369e-04.
# Adjusting learning rate of group 0 to 3.0419e-04.
# Adjusting learning rate of group 0 to 3.0469e-04.
# Adjusting learning rate of group 0 to 3.0519e-04.
# Adjusting learning rate of group 0 to 3.0569e-04.
# Adjusting learning rate of group 0 to 3.0619e-04.
# Adjusting learning rate of group 0 to 3.0668e-04.
# Adjusting learning rate of group 0 to 3.0718e-04.
# Adjusting learning rate of group 0 to 3.0768e-04.
# Adjusting learning rate of group 0 to 3.0818e-04.
# Adjusting learning rate of group 0 to 3.0868e-04.
# Adjusting learning rate of group 0 to 3.0918e-04.
# Adjusting learning rate of group 0 to 3.0968e-04.
# Adjusting learning rate of group 0 to 3.1018e-04.
# Adjusting learning rate of group 0 to 3.1068e-04.
# Adjusting learning rate of group 0 to 3.1117e-04.
# Adjusting learning rate of group 0 to 3.1167e-04.
# Adjusting learning rate of group 0 to 3.1217e-04.
# Adjusting learning rate of group 0 to 3.1267e-04.
# Adjusting learning rate of group 0 to 3.1317e-04.
# Adjusting learning rate of group 0 to 3.1367e-04.
# Adjusting learning rate of group 0 to 3.1417e-04.
# Adjusting learning rate of group 0 to 3.1467e-04.
# Adjusting learning rate of group 0 to 3.1516e-04.
# Adjusting learning rate of group 0 to 3.1566e-04.
# Adjusting learning rate of group 0 to 3.1616e-04.
# Adjusting learning rate of group 0 to 3.1666e-04.
# Adjusting learning rate of group 0 to 3.1716e-04.
# Adjusting learning rate of group 0 to 3.1766e-04.
# Adjusting learning rate of group 0 to 3.1816e-04.
# Adjusting learning rate of group 0 to 3.1866e-04.
# Adjusting learning rate of group 0 to 3.1915e-04.
# Adjusting learning rate of group 0 to 3.1965e-04.
# Adjusting learning rate of group 0 to 3.2015e-04.
# Adjusting learning rate of group 0 to 3.2065e-04.
# Adjusting learning rate of group 0 to 3.2115e-04.
# Adjusting learning rate of group 0 to 3.2165e-04.
# trigger times: 3
# Loss after 317424 batches: 0.0452
# Adjusting learning rate of group 0 to 3.2215e-04.
# Adjusting learning rate of group 0 to 3.2265e-04.
# Adjusting learning rate of group 0 to 3.2314e-04.
# Adjusting learning rate of group 0 to 3.2364e-04.
# Adjusting learning rate of group 0 to 3.2414e-04.
# Adjusting learning rate of group 0 to 3.2464e-04.
# Adjusting learning rate of group 0 to 3.2514e-04.
# Adjusting learning rate of group 0 to 3.2564e-04.
# Adjusting learning rate of group 0 to 3.2614e-04.
# Adjusting learning rate of group 0 to 3.2664e-04.
# Adjusting learning rate of group 0 to 3.2714e-04.
# Adjusting learning rate of group 0 to 3.2763e-04.
# Adjusting learning rate of group 0 to 3.2813e-04.
# Adjusting learning rate of group 0 to 3.2863e-04.
# Adjusting learning rate of group 0 to 3.2913e-04.
# Adjusting learning rate of group 0 to 3.2963e-04.
# Adjusting learning rate of group 0 to 3.3013e-04.
# Adjusting learning rate of group 0 to 3.3063e-04.
# Adjusting learning rate of group 0 to 3.3113e-04.
# Adjusting learning rate of group 0 to 3.3162e-04.
# Adjusting learning rate of group 0 to 3.3212e-04.
# Adjusting learning rate of group 0 to 3.3262e-04.
# Adjusting learning rate of group 0 to 3.3312e-04.
# Adjusting learning rate of group 0 to 3.3362e-04.
# Adjusting learning rate of group 0 to 3.3412e-04.
# Adjusting learning rate of group 0 to 3.3462e-04.
# Adjusting learning rate of group 0 to 3.3512e-04.
# Adjusting learning rate of group 0 to 3.3561e-04.
# Adjusting learning rate of group 0 to 3.3611e-04.
# Adjusting learning rate of group 0 to 3.3661e-04.
# Adjusting learning rate of group 0 to 3.3711e-04.
# Adjusting learning rate of group 0 to 3.3761e-04.
# Adjusting learning rate of group 0 to 3.3811e-04.
# Adjusting learning rate of group 0 to 3.3861e-04.
# Adjusting learning rate of group 0 to 3.3911e-04.
# Adjusting learning rate of group 0 to 3.3960e-04.
# Adjusting learning rate of group 0 to 3.4010e-04.
# Adjusting learning rate of group 0 to 3.4060e-04.
# Adjusting learning rate of group 0 to 3.4110e-04.
# Adjusting learning rate of group 0 to 3.4160e-04.
# trigger times: 4
# Loss after 337263 batches: 0.0451
# Adjusting learning rate of group 0 to 3.4210e-04.
# Adjusting learning rate of group 0 to 3.4260e-04.
# Adjusting learning rate of group 0 to 3.4310e-04.
# Adjusting learning rate of group 0 to 3.4360e-04.
# Adjusting learning rate of group 0 to 3.4409e-04.
# Adjusting learning rate of group 0 to 3.4459e-04.
# Adjusting learning rate of group 0 to 3.4509e-04.
# Adjusting learning rate of group 0 to 3.4559e-04.
# Adjusting learning rate of group 0 to 3.4609e-04.
# Adjusting learning rate of group 0 to 3.4659e-04.
# Adjusting learning rate of group 0 to 3.4709e-04.
# Adjusting learning rate of group 0 to 3.4759e-04.
# Adjusting learning rate of group 0 to 3.4808e-04.
# Adjusting learning rate of group 0 to 3.4858e-04.
# Adjusting learning rate of group 0 to 3.4908e-04.
# Adjusting learning rate of group 0 to 3.4958e-04.
# Adjusting learning rate of group 0 to 3.5008e-04.
# Adjusting learning rate of group 0 to 3.5058e-04.
# Adjusting learning rate of group 0 to 3.5108e-04.
# Adjusting learning rate of group 0 to 3.5158e-04.
# Adjusting learning rate of group 0 to 3.5207e-04.
# Adjusting learning rate of group 0 to 3.5257e-04.
# Adjusting learning rate of group 0 to 3.5307e-04.
# Adjusting learning rate of group 0 to 3.5357e-04.
# Adjusting learning rate of group 0 to 3.5407e-04.
# Adjusting learning rate of group 0 to 3.5457e-04.
# Adjusting learning rate of group 0 to 3.5507e-04.
# Adjusting learning rate of group 0 to 3.5557e-04.
# Adjusting learning rate of group 0 to 3.5606e-04.
# Adjusting learning rate of group 0 to 3.5656e-04.
# Adjusting learning rate of group 0 to 3.5706e-04.
# Adjusting learning rate of group 0 to 3.5756e-04.
# Adjusting learning rate of group 0 to 3.5806e-04.
# Adjusting learning rate of group 0 to 3.5856e-04.
# Adjusting learning rate of group 0 to 3.5906e-04.
# Adjusting learning rate of group 0 to 3.5956e-04.
# Adjusting learning rate of group 0 to 3.6006e-04.
# Adjusting learning rate of group 0 to 3.6055e-04.
# Adjusting learning rate of group 0 to 3.6105e-04.
# Adjusting learning rate of group 0 to 3.6155e-04.
# trigger times: 5
# Early stopping!
# Start to test process.
# Loss after 357102 batches: 0.0449
# Time to train on one home:  528.470091342926
# <br/>Waiting for W&B process to finish, PID 612524<br/>Program ended successfully.
# Find user logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_214334-1xjifatk\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_214334-1xjifatk\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>590</td></tr><tr><td>_timestamp</td><td>1639796004</td></tr><tr><td>_step</td><td>18</td></tr><tr><td>Training_MSE</td><td>0.04488</td></tr><tr><td>Validation_MSE</td><td>0.0007</td></tr><tr><td>Training_R2</td><td>-138.50897</td></tr><tr><td>Validation_R2</td><td>-0.4513</td></tr><tr><td>Training_F1</td><td>0.51702</td></tr><tr><td>Validation_F1</td><td>0.91547</td></tr><tr><td>Training_NEP</td><td>1.11286</td></tr><tr><td>Validation_NEP</td><td>0.18468</td></tr><tr><td>Training_NDE</td><td>0.81265</td></tr><tr><td>Validation_NDE</td><td>0.0101</td></tr><tr><td>Training_MAE</td><td>19.36629</td></tr><tr><td>Validation_MAE</td><td>1.77776</td></tr><tr><td>Test_MSE</td><td>0.00575</td></tr><tr><td>Test_R2_Value</td><td>-0.56722</td></tr><tr><td>Test_F1_Score</td><td>0.90247</td></tr><tr><td>Test_NEP</td><td>0.2581</td></tr><tr><td>Test_NDE</td><td>0.07324</td></tr><tr><td>Test_MAE</td><td>2.55522</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇███</td></tr><tr><td>_step</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>Training_MSE</td><td>█▇▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation_MSE</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_R2</td><td>▁▃▅▆▇▇████████████</td></tr><tr><td>Validation_R2</td><td>▁▆▇███████████████</td></tr><tr><td>Training_F1</td><td>▆▆▆▆▇▇█▁▇▇▇▇▇█████</td></tr><tr><td>Validation_F1</td><td>▁▄▅▆▆▇▇███████████</td></tr><tr><td>Training_NEP</td><td>█▇▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation_NEP</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_NDE</td><td>█▆▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation_NDE</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training_MAE</td><td>█▇▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation_MAE</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_R2_Value</td><td>▁</td></tr><tr><td>Test_F1_Score</td><td>▁</td></tr><tr><td>Test_NEP</td><td>▁</td></tr><tr><td>Test_NDE</td><td>▁</td></tr><tr><td>Test_MAE</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">electric-bird-12</strong>: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/1xjifatk" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/1xjifatk</a><br/>
# [I 2021-12-17 21:53:28,602] Trial 0 finished with value: 0.005754861515015364 and parameters: {'hidden_size_1': 114, 'hidden_size_2': 139, 'fc1': 232, 'fc2': 18, 'weight_decay': 0.035205333801131625, 'learning_rate': 2.4241137885020765e-06, 'window_size': 126}. Best is trial 0 with value: 0.005754861515015364.
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.19<br/>
#                 Syncing run <strong style="color:#cdcd00">denim-wind-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nilm/Drye1_optimization_new" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new</a><br/>
#                 Run page: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/2lxj9jmu" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/2lxj9jmu</a><br/>
#                 Run data is saved locally in <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_215328-2lxj9jmu</code><br/><br/>
# LSTM(
#   (conv1): Conv1d(1, 16, kernel_size=(7,), stride=(1,), padding=(3,))
#   (lstm1): LSTM(16, 110, num_layers=2, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(220, 95, num_layers=2, batch_first=True, bidirectional=True)
#   (linear1): Linear(in_features=190, out_features=349, bias=True)
#   (linear2): Linear(in_features=349, out_features=26, bias=True)
#   (linear3): Linear(in_features=26, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Window Length:  133
# Adjusting learning rate of group 0 to 1.6414e-04.
# Adjusting learning rate of group 0 to 1.6455e-04.
# Adjusting learning rate of group 0 to 1.6497e-04.
# Adjusting learning rate of group 0 to 1.6539e-04.
# Adjusting learning rate of group 0 to 1.6581e-04.
# Adjusting learning rate of group 0 to 1.6623e-04.
# Adjusting learning rate of group 0 to 1.6664e-04.
# Adjusting learning rate of group 0 to 1.6706e-04.
# Adjusting learning rate of group 0 to 1.6748e-04.
# Adjusting learning rate of group 0 to 1.6790e-04.
# Adjusting learning rate of group 0 to 1.6832e-04.
# Adjusting learning rate of group 0 to 1.6873e-04.
# Adjusting learning rate of group 0 to 1.6915e-04.
# Adjusting learning rate of group 0 to 1.6957e-04.
# Adjusting learning rate of group 0 to 1.6999e-04.
# Adjusting learning rate of group 0 to 1.7041e-04.
# Adjusting learning rate of group 0 to 1.7082e-04.
# Adjusting learning rate of group 0 to 1.7124e-04.
# Adjusting learning rate of group 0 to 1.7166e-04.
# Adjusting learning rate of group 0 to 1.7208e-04.
# Adjusting learning rate of group 0 to 1.7250e-04.
# Adjusting learning rate of group 0 to 1.7291e-04.
# Adjusting learning rate of group 0 to 1.7333e-04.
# Adjusting learning rate of group 0 to 1.7375e-04.
# Adjusting learning rate of group 0 to 1.7417e-04.
# Adjusting learning rate of group 0 to 1.7459e-04.
# Adjusting learning rate of group 0 to 1.7500e-04.
# Adjusting learning rate of group 0 to 1.7542e-04.
# Adjusting learning rate of group 0 to 1.7584e-04.
# Adjusting learning rate of group 0 to 1.7626e-04.
# Adjusting learning rate of group 0 to 1.7667e-04.
# Adjusting learning rate of group 0 to 1.7709e-04.
# Adjusting learning rate of group 0 to 1.7751e-04.
# Adjusting learning rate of group 0 to 1.7793e-04.
# Adjusting learning rate of group 0 to 1.7835e-04.
# Adjusting learning rate of group 0 to 1.7876e-04.
# Adjusting learning rate of group 0 to 1.7918e-04.
# Adjusting learning rate of group 0 to 1.7960e-04.
# Adjusting learning rate of group 0 to 1.8002e-04.
# Adjusting learning rate of group 0 to 1.8044e-04.
# trigger times: 0
# Loss after 19103 batches: 0.1002
# Adjusting learning rate of group 0 to 1.8085e-04.
# Adjusting learning rate of group 0 to 1.8127e-04.
# Adjusting learning rate of group 0 to 1.8169e-04.
# Adjusting learning rate of group 0 to 1.8211e-04.
# Adjusting learning rate of group 0 to 1.8253e-04.
# Adjusting learning rate of group 0 to 1.8294e-04.
# Adjusting learning rate of group 0 to 1.8336e-04.
# Adjusting learning rate of group 0 to 1.8378e-04.
# Adjusting learning rate of group 0 to 1.8420e-04.
# Adjusting learning rate of group 0 to 1.8462e-04.
# Adjusting learning rate of group 0 to 1.8503e-04.
# Adjusting learning rate of group 0 to 1.8545e-04.
# Adjusting learning rate of group 0 to 1.8587e-04.
# Adjusting learning rate of group 0 to 1.8629e-04.
# Adjusting learning rate of group 0 to 1.8671e-04.
# Adjusting learning rate of group 0 to 1.8712e-04.
# Adjusting learning rate of group 0 to 1.8754e-04.
# Adjusting learning rate of group 0 to 1.8796e-04.
# Adjusting learning rate of group 0 to 1.8838e-04.
# Adjusting learning rate of group 0 to 1.8879e-04.
# Adjusting learning rate of group 0 to 1.8921e-04.
# Adjusting learning rate of group 0 to 1.8963e-04.
# Adjusting learning rate of group 0 to 1.9005e-04.
# Adjusting learning rate of group 0 to 1.9047e-04.
# Adjusting learning rate of group 0 to 1.9088e-04.
# Adjusting learning rate of group 0 to 1.9130e-04.
# Adjusting learning rate of group 0 to 1.9172e-04.
# Adjusting learning rate of group 0 to 1.9214e-04.
# Adjusting learning rate of group 0 to 1.9256e-04.
# Adjusting learning rate of group 0 to 1.9297e-04.
# Adjusting learning rate of group 0 to 1.9339e-04.
# Adjusting learning rate of group 0 to 1.9381e-04.
# Adjusting learning rate of group 0 to 1.9423e-04.
# Adjusting learning rate of group 0 to 1.9465e-04.
# Adjusting learning rate of group 0 to 1.9506e-04.
# Adjusting learning rate of group 0 to 1.9548e-04.
# Adjusting learning rate of group 0 to 1.9590e-04.
# Adjusting learning rate of group 0 to 1.9632e-04.
# Adjusting learning rate of group 0 to 1.9674e-04.
# trigger times: 1
# Loss after 38206 batches: 0.0549
# Adjusting learning rate of group 0 to 1.9715e-04.
# Adjusting learning rate of group 0 to 1.9757e-04.
# Adjusting learning rate of group 0 to 1.9799e-04.
# Adjusting learning rate of group 0 to 1.9841e-04.
# Adjusting learning rate of group 0 to 1.9883e-04.
# Adjusting learning rate of group 0 to 1.9924e-04.
# Adjusting learning rate of group 0 to 1.9966e-04.
# Adjusting learning rate of group 0 to 2.0008e-04.
# Adjusting learning rate of group 0 to 2.0050e-04.
# Adjusting learning rate of group 0 to 2.0091e-04.
# Adjusting learning rate of group 0 to 2.0133e-04.
# Adjusting learning rate of group 0 to 2.0175e-04.
# ...
# Adjusting learning rate of group 0 to 3.1858e-04.
# Adjusting learning rate of group 0 to 3.1908e-04.
# Adjusting learning rate of group 0 to 3.1957e-04.
# Adjusting learning rate of group 0 to 3.2007e-04.
# Adjusting learning rate of group 0 to 3.2056e-04.
# Adjusting learning rate of group 0 to 3.2106e-04.
# Adjusting learning rate of group 0 to 3.2155e-04.
# Adjusting learning rate of group 0 to 3.2205e-04.
# Adjusting learning rate of group 0 to 3.2254e-04.
# Adjusting learning rate of group 0 to 3.2304e-04.
# Adjusting learning rate of group 0 to 3.2353e-04.
# Adjusting learning rate of group 0 to 3.2403e-04.
# Adjusting learning rate of group 0 to 3.2452e-04.
# Adjusting learning rate of group 0 to 3.2502e-04.
# Adjusting learning rate of group 0 to 3.2551e-04.
# Adjusting learning rate of group 0 to 3.2601e-04.
# Adjusting learning rate of group 0 to 3.2650e-04.
# trigger times: 4
# Loss after 316035 batches: 0.0593
# Adjusting learning rate of group 0 to 3.2700e-04.
# Adjusting learning rate of group 0 to 3.2749e-04.
# Adjusting learning rate of group 0 to 3.2799e-04.
# Adjusting learning rate of group 0 to 3.2848e-04.
# Adjusting learning rate of group 0 to 3.2898e-04.
# Adjusting learning rate of group 0 to 3.2947e-04.
# Adjusting learning rate of group 0 to 3.2997e-04.
# Adjusting learning rate of group 0 to 3.3046e-04.
# Adjusting learning rate of group 0 to 3.3096e-04.
# Adjusting learning rate of group 0 to 3.3145e-04.
# Adjusting learning rate of group 0 to 3.3195e-04.
# Adjusting learning rate of group 0 to 3.3244e-04.
# Adjusting learning rate of group 0 to 3.3294e-04.
# Adjusting learning rate of group 0 to 3.3343e-04.
# Adjusting learning rate of group 0 to 3.3393e-04.
# Adjusting learning rate of group 0 to 3.3442e-04.
# Adjusting learning rate of group 0 to 3.3491e-04.
# Adjusting learning rate of group 0 to 3.3541e-04.
# Adjusting learning rate of group 0 to 3.3590e-04.
# Adjusting learning rate of group 0 to 3.3640e-04.
# Adjusting learning rate of group 0 to 3.3689e-04.
# Adjusting learning rate of group 0 to 3.3739e-04.
# Adjusting learning rate of group 0 to 3.3788e-04.
# Adjusting learning rate of group 0 to 3.3838e-04.
# Adjusting learning rate of group 0 to 3.3887e-04.
# Adjusting learning rate of group 0 to 3.3937e-04.
# Adjusting learning rate of group 0 to 3.3986e-04.
# Adjusting learning rate of group 0 to 3.4036e-04.
# Adjusting learning rate of group 0 to 3.4085e-04.
# Adjusting learning rate of group 0 to 3.4135e-04.
# Adjusting learning rate of group 0 to 3.4184e-04.
# Adjusting learning rate of group 0 to 3.4234e-04.
# Adjusting learning rate of group 0 to 3.4283e-04.
# Adjusting learning rate of group 0 to 3.4333e-04.
# Adjusting learning rate of group 0 to 3.4382e-04.
# Adjusting learning rate of group 0 to 3.4432e-04.
# Adjusting learning rate of group 0 to 3.4481e-04.
# Adjusting learning rate of group 0 to 3.4531e-04.
# Adjusting learning rate of group 0 to 3.4580e-04.
# Adjusting learning rate of group 0 to 3.4630e-04.
# Adjusting learning rate of group 0 to 3.4679e-04.
# Adjusting learning rate of group 0 to 3.4729e-04.
# Adjusting learning rate of group 0 to 3.4778e-04.
# Adjusting learning rate of group 0 to 3.4828e-04.
# Adjusting learning rate of group 0 to 3.4877e-04.
# Adjusting learning rate of group 0 to 3.4927e-04.
# Adjusting learning rate of group 0 to 3.4976e-04.
# Adjusting learning rate of group 0 to 3.5026e-04.
# Adjusting learning rate of group 0 to 3.5075e-04.
# Adjusting learning rate of group 0 to 3.5124e-04.
# Adjusting learning rate of group 0 to 3.5174e-04.
# Adjusting learning rate of group 0 to 3.5223e-04.
# Adjusting learning rate of group 0 to 3.5273e-04.
# Adjusting learning rate of group 0 to 3.5322e-04.
# Adjusting learning rate of group 0 to 3.5372e-04.
# Adjusting learning rate of group 0 to 3.5421e-04.
# Adjusting learning rate of group 0 to 3.5471e-04.
# Adjusting learning rate of group 0 to 3.5520e-04.
# Adjusting learning rate of group 0 to 3.5570e-04.
# Adjusting learning rate of group 0 to 3.5619e-04.
# Adjusting learning rate of group 0 to 3.5669e-04.
# Adjusting learning rate of group 0 to 3.5718e-04.
# Adjusting learning rate of group 0 to 3.5768e-04.
# Adjusting learning rate of group 0 to 3.5817e-04.
# Adjusting learning rate of group 0 to 3.5867e-04.
# Adjusting learning rate of group 0 to 3.5916e-04.
# Adjusting learning rate of group 0 to 3.5966e-04.
# Adjusting learning rate of group 0 to 3.6015e-04.
# Adjusting learning rate of group 0 to 3.6065e-04.
# Adjusting learning rate of group 0 to 3.6114e-04.
# Adjusting learning rate of group 0 to 3.6164e-04.
# trigger times: 5
# Early stopping!
# Start to test process.
# Loss after 351150 batches: 0.0584
# Time to train on one home:  495.1583685874939
# <br/>Waiting for W&B process to finish, PID 716396<br/>Program ended successfully.
# Find user logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_215811-3nm9r6sg\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_215811-3nm9r6sg\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>551</td></tr><tr><td>_timestamp</td><td>1639796843</td></tr><tr><td>_step</td><td>10</td></tr><tr><td>Training_MSE</td><td>0.05839</td></tr><tr><td>Validation_MSE</td><td>0.00778</td></tr><tr><td>Training_R2</td><td>-278.3121</td></tr><tr><td>Validation_R2</td><td>-1.26132</td></tr><tr><td>Training_F1</td><td>0.32972</td></tr><tr><td>Validation_F1</td><td>0.81743</td></tr><tr><td>Training_NEP</td><td>1.15728</td></tr><tr><td>Validation_NEP</td><td>0.51634</td></tr><tr><td>Training_NDE</td><td>0.86307</td></tr><tr><td>Validation_NDE</td><td>0.23711</td></tr><tr><td>Training_MAE</td><td>10.9063</td></tr><tr><td>Validation_MAE</td><td>2.42648</td></tr><tr><td>Test_MSE</td><td>0.01</td></tr><tr><td>Test_R2_Value</td><td>-1.21328</td></tr><tr><td>Test_F1_Score</td><td>0.8278</td></tr><tr><td>Test_NEP</td><td>0.46877</td></tr><tr><td>Test_NDE</td><td>0.12549</td></tr><tr><td>Test_MAE</td><td>2.13023</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▂▃▃▄▅▆▆▇██</td></tr><tr><td>_timestamp</td><td>▁▂▃▃▄▅▆▆▇██</td></tr><tr><td>_step</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>Training_MSE</td><td>█▅▃▂▂▁▁▁▁▁</td></tr><tr><td>Validation_MSE</td><td>█▁▁▂▁▁▂▂▁▃</td></tr><tr><td>Training_R2</td><td>▁▄▆▇▇█████</td></tr><tr><td>Validation_R2</td><td>▁██▇██▇▇█▇</td></tr><tr><td>Training_F1</td><td>▂▄▆▇█▁▅▆▆▆</td></tr><tr><td>Validation_F1</td><td>▁██▇██▇▇█▇</td></tr><tr><td>Training_NEP</td><td>█▇▄▃▂▂▁▁▁▁</td></tr><tr><td>Validation_NEP</td><td>█▁▂▃▁▂▃▃▁▄</td></tr><tr><td>Training_NDE</td><td>█▆▃▂▂▁▁▁▁▁</td></tr><tr><td>Validation_NDE</td><td>█▁▁▁▁▁▂▂▁▂</td></tr><tr><td>Training_MAE</td><td>█▇▄▃▂▂▁▁▁▁</td></tr><tr><td>Validation_MAE</td><td>█▁▂▃▁▂▃▃▁▄</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_R2_Value</td><td>▁</td></tr><tr><td>Test_F1_Score</td><td>▁</td></tr><tr><td>Test_NEP</td><td>▁</td></tr><tr><td>Test_NDE</td><td>▁</td></tr><tr><td>Test_MAE</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">dulcet-darkness-14</strong>: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/3nm9r6sg" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/3nm9r6sg</a><br/>
# [I 2021-12-17 22:07:27,504] Trial 2 finished with value: 0.010004283860325813 and parameters: {'hidden_size_1': 62, 'hidden_size_2': 125, 'fc1': 248, 'fc2': 17, 'weight_decay': 0.04894758905557665, 'learning_rate': 1.028985278398668e-05, 'window_size': 57}. Best is trial 0 with value: 0.005754861515015364.
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.19<br/>
#                 Syncing run <strong style="color:#cdcd00">fast-vortex-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nilm/Drye1_optimization_new" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new</a><br/>
#                 Run page: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/35xau85v" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/35xau85v</a><br/>
#                 Run data is saved locally in <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_220727-35xau85v</code><br/><br/>
# LSTM(
#   (conv1): Conv1d(1, 16, kernel_size=(7,), stride=(1,), padding=(3,))
#   (lstm1): LSTM(16, 96, num_layers=2, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(192, 133, num_layers=2, batch_first=True, bidirectional=True)
#   (linear1): Linear(in_features=266, out_features=215, bias=True)
#   (linear2): Linear(in_features=215, out_features=17, bias=True)
#   (linear3): Linear(in_features=17, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Window Length:  185
# Adjusting learning rate of group 0 to 7.9594e-06.
# <br/>Waiting for W&B process to finish, PID 1211436<br/>Program failed with code 1.  Press ctrl-c to abort syncing.
# Find user logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_220727-35xau85v\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\aar245\Desktop\privacy_preserving_nn\src\wandb\run-20211217_220727-35xau85v\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# </table>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">fast-vortex-15</strong>: <a href="https://wandb.ai/nilm/Drye1_optimization_new/runs/35xau85v" target="_blank">https://wandb.ai/nilm/Drye1_optimization_new/runs/35xau85v</a><br/>
# [W 2021-12-17 22:09:46,511] Trial 3 failed because of the following error: RuntimeError('CUDA out of memory. Tried to allocate 468.00 MiB (GPU 0; 8.00 GiB total capacity; 2.18 GiB already allocated; 368.02 MiB free; 2.64 GiB reserved in total by PyTorch)')
# Traceback (most recent call last):
#   File "C:\Users\aar245\Anaconda3\envs\test_env\lib\site-packages\optuna\study\_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\aar245\AppData\Local\Temp\61/ipykernel_1807508/48718933.py", line 12, in objective
#     model, result = model_pipeline(
#   File "C:\Users\aar245\AppData\Local\Temp\61/ipykernel_1807508/3521383735.py", line 30, in model_pipeline
#     model, example_ct, batch_ct, all_epochs = train(
#   File "C:\Users\aar245\Desktop\privacy_preserving_nn\src\train.py", line 44, in train
#     train_predictions, train_true_vals, loss = train_batch(features, labels, model, optimizer, criterion)
#   File "C:\Users\aar245\Desktop\privacy_preserving_nn\src\train.py", line 181, in train_batch
#     loss.backward()
#   File "C:\Users\aar245\Anaconda3\envs\test_env\lib\site-packages\torch\tensor.py", line 221, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "C:\Users\aar245\Anaconda3\envs\test_env\lib\site-packages\torch\autograd\__init__.py", line 130, in backward
#     Variable._execution_engine.run_backward(
# RuntimeError: CUDA out of memory. Tried to allocate 468.00 MiB (GPU 0; 8.00 GiB total capacity; 2.18 GiB already allocated; 368.02 MiB free; 2.64 GiB reserved in total by PyTorch)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\61/ipykernel_1807508/685698000.py in <module>
#       1 if __name__ == "__main__":
#       2     study = optuna.create_study(direction='minimize')
# ----> 3     study.optimize(objective, n_trials=25)
#       4
#       5     print("best trial:")
#
# ~\Anaconda3\envs\test_env\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~\Anaconda3\envs\test_env\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~\Anaconda3\envs\test_env\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~\Anaconda3\envs\test_env\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     262
#     263     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 264         raise func_err
#     265     return trial
#     266
#
# ~\Anaconda3\envs\test_env\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\61/ipykernel_1807508/48718933.py in objective(trial)
#      10     }
#      11
# ---> 12     model, result = model_pipeline(
#      13         config_,
#      14         'may_june_july',
#
# ~\AppData\Local\Temp\61/ipykernel_1807508/3521383735.py in model_pipeline(hyperparameters, train_months, test_month, appliance, window_length, train_buildings, test_buildings, params)
#      28         time_log = time.time()
#      29         train_loader = make_train_data(config, train_months, appliance, window_length, train_buildings)
# ---> 30         model, example_ct, batch_ct, all_epochs = train(
#      31             model,
#      32             train_loader,
#
# ~\Desktop\privacy_preserving_nn\src\train.py in train(model, loader, validation_loader, criterion, optimizer, config, example_ct, batch_ct, all_epochs, scheduler)
#      42         all_epochs += 1
#      43         for _, (features, labels) in enumerate(loader):
# ---> 44             train_predictions, train_true_vals, loss = train_batch(features, labels, model, optimizer, criterion)
#      45             epoch_total_loss += float(loss.item())
#      46             epoch_predictions.append(train_predictions)
#
# ~\Desktop\privacy_preserving_nn\src\train.py in train_batch(features, labels, model, optimizer, criterion)
#     179
#     180     optimizer.zero_grad()
# --> 181     loss.backward()
#     182
#     183     optimizer.step()
#
# ~\Anaconda3\envs\test_env\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\Anaconda3\envs\test_env\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# RuntimeError: CUDA out of memory. Tried to allocate 468.00 MiB (GPU 0; 8.00 GiB total capacity; 2.18 GiB already allocated; 368.02 MiB free; 2.64 GiB reserved in total by PyTorch)

# %%
homes = load_all_houses_with_device(config_file.path, 'drye1')


drye1_homes = homes['dataid'].loc[homes['dataid'] != 1706].unique()


final_results = {}
random.seed(5)
for j in drye1_homes:
    for i in range(10):
        model, per_house_result = model_pipeline(
        config_,
        'may_june_july',
        'may_june_july',
        'drye1',
        100,
        [j],
        [1706])
        result = {j: per_house_result}
        final_results.update(result)

# %%
Trial 2 finished with value: 0.048315126448869705 and parameters:
        {'hidden_size_1': 30,
         'hidden_size_2': 123,
         'fc1': 299, 'fc2': 18,
         'weight_decay': 0.005038971768580936,
         'learning_rate': 0.000624235019529808,
         'window_size': 280}.
        Best is trial 2 with value: 0.048315126448869705

# %%
Trial 21 finished with value: 0.05254843831062317 and parameters:
        {'hidden_size_1': 114,
         'hidden_size_2': 83,
         'fc1': 182, 'fc2': 28,
         'weight_decay': 0.07786274942658475,
         'learning_rate': 0.000305222263105676,
         'window_size': 2}
        Best is trial 21 with value: 0.05254843831062317

# %%
best trial:
[0.0510893389582634]
{'hidden_size_1': 91,
 'hidden_size_2': 138,
 'fc1': 381, 'fc2': 27,
 'weight_decay': 0.009457205008621654,
 'learning_rate': 0.0003242301834854019,
 'window_size': 141}

# %%
best trial:
[0.037125106900930405]
{'hidden_size_1': 44,
 'hidden_size_2': 129,
 'fc1': 340, 'fc2': 22,
 'weight_decay': 0.021543979275305797,
 'learning_rate': 0.00022534369918008793,
 'window_size': 169}

# %%
import numpy as np
y_sequence = []
def normalize_y(y_sequence):
    y_sequence = np.log(np.add(y_sequence, 1))
    try:
        return (y_sequence - np.min(y_sequence)) / (np.max(y_sequence) - np.min(y_sequence))
    except ValueError:  # raised if `y` is empty.
        return []

# %%
normalize_y(y_sequence)
